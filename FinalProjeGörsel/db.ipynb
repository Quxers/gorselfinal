-- %% [markdown]
-- # [görselfinals]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [görselfinals]    Script Date: 17.01.2023 17:52:14 ******/
CREATE DATABASE [görselfinals]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'görselfinals', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\görselfinals.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'görselfinals_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\görselfinals_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [görselfinals] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [görselfinals].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [görselfinals] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [görselfinals] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [görselfinals] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [görselfinals] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [görselfinals] SET ARITHABORT OFF 
GO
ALTER DATABASE [görselfinals] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [görselfinals] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [görselfinals] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [görselfinals] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [görselfinals] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [görselfinals] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [görselfinals] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [görselfinals] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [görselfinals] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [görselfinals] SET  DISABLE_BROKER 
GO
ALTER DATABASE [görselfinals] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [görselfinals] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [görselfinals] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [görselfinals] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [görselfinals] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [görselfinals] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [görselfinals] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [görselfinals] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [görselfinals] SET  MULTI_USER 
GO
ALTER DATABASE [görselfinals] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [görselfinals] SET DB_CHAINING OFF 
GO
ALTER DATABASE [görselfinals] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [görselfinals] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [görselfinals] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [görselfinals] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [görselfinals] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[Ders]

-- %%
USE [görselfinals]
GO

-- %%
/****** Object:  Table [dbo].[Ders]    Script Date: 17.01.2023 17:52:14 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Ders](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Ders_Adı] [nvarchar](50) NULL,
	[Ders_Kredisi] [int] NOT NULL,
	[Okul_Yönetim_Id] [int] NOT NULL,
	[Ders_Rengi] [int] NOT NULL,
 CONSTRAINT [PK_Ders] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Ogrenci]

-- %%
/****** Object:  Table [dbo].[Ogrenci]    Script Date: 17.01.2023 17:52:14 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Ogrenci](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Ad_Soyad] [nvarchar](50) NULL,
	[Kayıt_Tarihi] [datetime] NOT NULL,
	[Öğrenci_No] [nvarchar](50) NULL,
	[Doğum_Tarihi] [datetime] NOT NULL,
	[Bölümü] [nvarchar](50) NULL,
 CONSTRAINT [PK_Ogrenci] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[OgrenciDers]

-- %%
/****** Object:  Table [dbo].[OgrenciDers]    Script Date: 17.01.2023 17:52:14 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[OgrenciDers](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Ders_Id] [int] NOT NULL,
	[Ogrenci_Id] [int] NOT NULL,
 CONSTRAINT [PK_OgrenciDers] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Personel]

-- %%
/****** Object:  Table [dbo].[Personel]    Script Date: 17.01.2023 17:52:14 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Personel](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Ad_Soyad] [nvarchar](50) NULL,
	[Görevi] [nvarchar](50) NULL,
	[Yönetim_Tipi] [int] NOT NULL,
 CONSTRAINT [PK_Personel] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_Ders_OgrenciDers]

-- %%
ALTER TABLE [dbo].[Ders]  WITH CHECK ADD  CONSTRAINT [FK_Ders_OgrenciDers] FOREIGN KEY([Id])
REFERENCES [dbo].[OgrenciDers] ([Id])
GO
ALTER TABLE [dbo].[Ders] CHECK CONSTRAINT [FK_Ders_OgrenciDers]
GO

-- %% [markdown]
-- # [FK_OgrenciDers_Ogrenci]

-- %%
ALTER TABLE [dbo].[OgrenciDers]  WITH CHECK ADD  CONSTRAINT [FK_OgrenciDers_Ogrenci] FOREIGN KEY([Id])
REFERENCES [dbo].[Ogrenci] ([Id])
GO
ALTER TABLE [dbo].[OgrenciDers] CHECK CONSTRAINT [FK_OgrenciDers_Ogrenci]
GO

-- %% [markdown]
-- # [FK_Personel_Ders]

-- %%
ALTER TABLE [dbo].[Personel]  WITH CHECK ADD  CONSTRAINT [FK_Personel_Ders] FOREIGN KEY([Id])
REFERENCES [dbo].[Ders] ([Id])
GO
ALTER TABLE [dbo].[Personel] CHECK CONSTRAINT [FK_Personel_Ders]
GO

-- %% [markdown]
-- # [görselfinals]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [görselfinals] SET  READ_WRITE 
GO
